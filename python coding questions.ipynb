# %%
#1. Count word frequency
#2. Reverse a string (with/without slicing)
#3. Palindrome check
#4. First non-repeating character
#5. Character frequency count
#6. Reverse a list 
#7. Remove duplicates from a list
#8. Find duplicate elements in a list
#9. Find Largest & second largest element in a list
#10. Common elements between two lists
#11. Flatten a nested list
#12. Convert two lists into a dictionary
#13. Merge two dictionaries / two sorted list
#14. Move zeros to the end of the list
#15. Find the missing number in a list
#16. Find pair with given sum
#17. Fibonacci series
#18. Prime number check
#19. Remove consecutive duplicates
